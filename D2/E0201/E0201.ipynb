# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ## Ex. 0201a

# %%
# Import data 0201a
dataset = pd.read_csv('C:/MLC/D2/E1/Years Experience and Salary.csv')
x = dataset.loc[:,"YearsExperience"].values.reshape((-1,1))
y = dataset.loc[:,"Salary"].values.reshape((-1,1))

# Split training and test
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=1/4)

# Train a linear regression model
regressor = LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
# Plot
plt.scatter(x_train,y_train,color='red',label='Training')
plt.scatter(x_test,y_test,color='blue',label='Test')
plt.plot(x_train,regressor.predict(x_train), color='black', linewidth=2)
plt.title('Linear regression')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.legend()
plt.show()

# MSE
print("MSE training set:", mean_squared_error(y_train, regressor.predict(x_train)))
print("MSE test set:", mean_squared_error(y_test, regressor.predict(x_test)))
# Out:
# MSE training set: 25800684.41349779
# MSE test set: 47207182.936465584

# %% [markdown]
# # 0201b

# %%
# Import data 0201a
dataset2 = pd.read_csv('C:/MLC/D2/E1/data.csv')

x2 = dataset2.loc[:,"Height"].values.reshape((-1,1))
y2 = dataset2.loc[:,"Weight"].values.reshape((-1,1))

# Split training and test
x2_train, x2_test, y2_train, y2_test = train_test_split(x2,y2,test_size=1/4)

# Train a linear regression model
regressor2 = LinearRegression()
regressor2.fit(x2_train,y2_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
# Plot
plt.scatter(x2_train,y2_train,color='red',label='Training')
plt.scatter(x2_test,y2_test,color='blue',label='Test')
plt.plot(x2_train,regressor2.predict(x2_train), color='black', linewidth=2)
plt.title('Linear regression')
plt.xlabel('Height')
plt.ylabel('Weight')
plt.legend()
plt.show()

# MSE
print("MSE training set:", mean_squared_error(y2_train, regressor.predict(x2_train)))
print("MSE test set:", mean_squared_error(y2_test, regressor.predict(x2_test)))
# Out:
# MSE training set: 1637153876.7501738
# MSE test set: 1670525133.7392118
